# %%
# Import necessary libraries
import pandas as pd
import plotly.express as px
import plotly.graph_objects as go

# %%
# Loading in dataframe using API
url = "https://data.cityofnewyork.us/api/views/jr24-e7cr/rows.csv?accessType=DOWNLOAD"
df = pd.read_csv(url)

df.head()
# Out:
# <ipython-input-94-d1d04bdb71cc>:3: DtypeWarning:
#
# Columns (17) have mixed types. Specify dtype option on import or set low_memory=False.
#   Development Name Borough Account Name Location Meter AMR   Meter Scope  \
# 0            ADAMS   BRONX        ADAMS   BLD 05      NONE  BLD 01 to 07
# 1            ADAMS   BRONX        ADAMS   BLD 05      NONE  BLD 01 to 07
# 2            ADAMS   BRONX        ADAMS   BLD 05      NONE  BLD 01 to 07
# 3            ADAMS   BRONX        ADAMS   BLD 05      NONE  BLD 01 to 07
# 4            ADAMS   BRONX        ADAMS   BLD 05      NONE  BLD 01 to 07
#
#    TDS #  EDP  RC Code Funding Source  ... Meter Number Estimated  \
# 0  118.0  248  B011800        FEDERAL  ...      7223256         N
# 1  118.0  248  B011800        FEDERAL  ...      7223256         N
# 2  118.0  248  B011800        FEDERAL  ...      7223256         N
# 3  118.0  248  B011800        FEDERAL  ...      7223256         N
# 4  118.0  248  B011800        FEDERAL  ...      7223256         N
#
#    Current Charges   Rate Class Bill Analyzed Consumption (KWH)  KWH Charges  \
# 0         15396.82  GOV/NYC/068           Yes          128800.0      7387.97
# 1         14556.34  GOV/NYC/068           Yes          115200.0      6607.87
# 2         13904.98  GOV/NYC/068           Yes          103200.0      5919.55
# 3         14764.04  GOV/NYC/068           Yes          105600.0      6057.22
# 4         13729.54  GOV/NYC/068           Yes           97600.0      5598.34
#
#   Consumption (KW) KW Charges  Other charges
# 0            216.0     2808.0        5200.85
# 1            224.0     2912.0        5036.47
# 2            216.0     2808.0        5177.43
# 3            208.0     2704.0        6002.82
# 4            216.0     2808.0        5323.20
#
# [5 rows x 27 columns]

# %%
# Column cleanup & data range (date)
df.columns = df.columns.str.strip().str.lower().str.replace(" ", "_")
df['revenue_month'] = pd.to_datetime(df['revenue_month'], errors='coerce')
print(df['revenue_month'].min(), df['revenue_month'].max())
# Out:
# 2010-01-01 00:00:00 2024-12-01 00:00:00

# %%
# Renaming 'revenue_month' to 'period'
df.rename(columns={'revenue_month': 'period'}, inplace=True)

# Data cleaning for other fields
df.columns = df.columns.str.strip().str.lower().str.replace(" ", "_")

df['borough'] = df['borough'].str.upper().str.strip()
df = df[df['borough'].isin(['BROOKLYN', 'MANHATTAN', 'BRONX', 'QUEENS', 'STATEN ISLAND'])]
df = df[df['consumption_(kwh)'].notnull() & (df['consumption_(kwh)'] > 0)]
df = df.sort_values('period')

# %%
# Creating 'covid_phase' to categorize before, during, and after pandemic impacts
df['covid_phase'] = pd.cut(
    df['period'],
    bins=[
        pd.to_datetime('2009-12-31'),  # before any data
        pd.to_datetime('2020-02-29'),  # end of pre-COVID
        pd.to_datetime('2021-12-31'),  # end of intense COVID period
        pd.to_datetime('2025-01-01')   # future
    ],
    labels=['Before', 'COVID', 'After'],
)

df['covid_phase'] = pd.Categorical(
    df['covid_phase'],
    categories=['Before', 'COVID', 'After'],
    ordered=True
)

# %%
# Checking entries per year
df['year'] = df['period'].dt.year
year_counts = df['year'].value_counts().sort_index()
print(year_counts)
# Out:
# year
# 2010    26139
# 2012    25936
# 2013    25901
# 2014    25532
# 2015    25729
# 2016    25656
# 2017    24429
# 2019    24169
# 2020    33703
# 2021    25459
# 2022    25243
# 2023    24955
# 2024    25088
# Name: count, dtype: int64

# %%
# Defining 'phase_summary'
phase_summary = df.groupby('covid_phase')[['consumption_(kwh)', 'current_charges']].sum().reset_index()
phase_summary.columns = ['COVID Phase', 'Total kWh', 'Total Cost ($)']
# Out:
# <ipython-input-86-3804ed08413f>:2: FutureWarning:
#
# The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.

# %% [markdown]
# **Visuals For Pandemic Impact**

# %%
# Highest and Lowest Peaks in Cost During COVID
monthly_cost = (
    df.groupby('period', as_index=False)['current_charges']
    .sum()
    .assign(current_charges=lambda x: x['current_charges'] / 1_000_000)
)

covid_range = (monthly_cost['period'] >= '2020-03') & (monthly_cost['period'] <= '2021-12')
top_peaks = monthly_cost[covid_range].nlargest(2, 'current_charges')
lowest_point = monthly_cost[covid_range].nsmallest(1, 'current_charges')

fig = go.Figure()

# Line plot
fig.add_trace(go.Scatter(
    x=monthly_cost['period'], y=monthly_cost['current_charges'],
    mode='lines', name='Cost',
    line=dict(color='teal')
))

# Peak markers
for _, row in top_peaks.iterrows():
    fig.add_trace(go.Scatter(
        x=[row['period']], y=[row['current_charges']],
        mode='markers+text',
        marker=dict(size=8, color='blue'),
        text=[f"{row['period'].strftime('%b %Y')}:<br>${row['current_charges']:.1f}M"],
        textposition='top center',
        showlegend=False
    ))

# Lowest point marker
for _, row in lowest_point.iterrows():
    fig.add_trace(go.Scatter(
        x=[row['period']], y=[row['current_charges']],
        mode='markers+text',
        marker=dict(size=8, color='blue'),
        text=[f"{row['period'].strftime('%b %Y')}: ${row['current_charges']:.1f}M"],
        textposition='bottom center',
        showlegend=False
    ))

# COVID shading
fig.add_vrect(
    x0="2020-03-01", x1="2021-12-31",
    fillcolor="red", opacity=0.1,
    layer="below", line_width=0,
    annotation_text="[COVID Phase]", annotation_position="top left"
)

# Layout
fig.update_layout(
    title="Pandemic Impact on Electricity Costs (2010–2024)",
    yaxis_title="Monthly Cost (Million $)",
    xaxis_title="Date (Month & Year)",
    template="simple_white",
    hovermode="x unified"
)

fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="11a389ec-ea51-4bb9-876c-f586937f219b" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("11a389ec-ea51-4bb9-876c-f586937f219b")) {                    Plotly.newPlot(                        "11a389ec-ea51-4bb9-876c-f586937f219b",                        [{"line":{"color":"teal"},"mode":"lines","name":"Cost","x":["2010-01-01T00:00:00","2010-02-01T00:00:00","2010-03-01T00:00:00","2010-04-01T00:00:00","2010-05-01T00:00:00","2010-06-01T00:00:00","2010-07-01T00:00:00","2010-08-01T00:00:00","2010-09-01T00:00:00","2010-10-01T00:00:00","2010-11-01T00:00:00","2010-12-01T00:00:00","2012-01-01T00:00:00","2012-02-01T00:00:00","2012-03-01T00:00:00","2012-04-01T00:00:00","2012-05-01T00:00:00","2012-06-01T00:00:00","2012-07-01T00:00:00","2012-08-01T00:00:00","2012-09-01T00:00:00","2012-10-01T00:00:00","2012-11-01T00:00:00","2012-12-01T00:00:00","2013-01-01T00:00:00","2013-02-01T00:00:00","2013-03-01T00:00:00","2013-04-01T00:00:00","2013-05-01T00:00:00","2013-06-01T00:00:00","2013-07-01T00:00:00","2013-08-01T00:00:00","2013-09-01T00:00:00","2013-10-01T00:00:00","2013-11-01T00:00:00","2013-12-01T00:00:00","2014-01-01T00:00:00","2014-02-01T00:00:00","2014-03-01T00:00:00","2014-04-01T00:00:00","2014-05-01T00:00:00","2014-06-01T00:00:00","2014-07-01T00:00:00","2014-08-01T00:00:00","2014-09-01T00:00:00","2014-10-01T00:00:00","2014-11-01T00:00:00","2014-12-01T00:00:00","2015-01-01T00:00:00","2015-02-01T00:00:00","2015-03-01T00:00:00","2015-04-01T00:00:00","2015-05-01T00:00:00","2015-06-01T00:00:00","2015-07-01T00:00:00","2015-08-01T00:00:00","2015-09-01T00:00:00","2015-10-01T00:00:00","2015-11-01T00:00:00","2015-12-01T00:00:00","2016-01-01T00:00:00","2016-02-01T00:00:00","2016-03-01T00:00:00","2016-04-01T00:00:00","2016-05-01T00:00:00","2016-06-01T00:00:00","2016-07-01T00:00:00","2016-08-01T00:00:00","2016-09-01T00:00:00","2016-10-01T00:00:00","2016-11-01T00:00:00","2016-12-01T00:00:00","2017-01-01T00:00:00","2017-02-01T00:00:00","2017-03-01T00:00:00","2017-04-01T00:00:00","2017-05-01T00:00:00","2017-06-01T00:00:00","2017-07-01T00:00:00","2017-08-01T00:00:00","2017-09-01T00:00:00","2017-10-01T00:00:00","2017-11-01T00:00:00","2017-12-01T00:00:00","2019-01-01T00:00:00","2019-02-01T00:00:00","2019-03-01T00:00:00","2019-04-01T00:00:00","2019-05-01T00:00:00","2019-06-01T00:00:00","2019-07-01T00:00:00","2019-08-01T00:00:00","2019-09-01T00:00:00","2019-10-01T00:00:00","2019-11-01T00:00:00","2019-12-01T00:00:00","2020-01-01T00:00:00","2020-02-01T00:00:00","2020-03-01T00:00:00","2020-04-01T00:00:00","2020-05-01T00:00:00","2020-06-01T00:00:00","2020-07-01T00:00:00","2020-08-01T00:00:00","2020-09-01T00:00:00","2020-10-01T00:00:00","2020-11-01T00:00:00","2020-12-01T00:00:00","2021-01-01T00:00:00","2021-02-01T00:00:00","2021-03-01T00:00:00","2021-04-01T00:00:00","2021-05-01T00:00:00","2021-06-01T00:00:00","2021-07-01T00:00:00","2021-08-01T00:00:00","2021-09-01T00:00:00","2021-10-01T00:00:00","2021-11-01T00:00:00","2021-12-01T00:00:00","2022-01-01T00:00:00","2022-02-01T00:00:00","2022-03-01T00:00:00","2022-04-01T00:00:00","2022-05-01T00:00:00","2022-06-01T00:00:00","2022-07-01T00:00:00","2022-08-01T00:00:00","2022-09-01T00:00:00","2022-10-01T00:00:00","2022-11-01T00:00:00","2022-12-01T00:00:00","2023-01-01T00:00:00","2023-02-01T00:00:00","2023-03-01T00:00:00","2023-04-01T00:00:00","2023-05-01T00:00:00","2023-06-01T00:00:00","2023-07-01T00:00:00","2023-08-01T00:00:00","2023-09-01T00:00:00","2023-10-01T00:00:00","2023-11-01T00:00:00","2023-12-01T00:00:00","2024-01-01T00:00:00","2024-02-01T00:00:00","2024-03-01T00:00:00","2024-04-01T00:00:00","2024-05-01T00:00:00","2024-06-01T00:00:00","2024-07-01T00:00:00","2024-08-01T00:00:00","2024-09-01T00:00:00","2024-10-01 ...

# %%
# Bar Chart

# Grouping and sorting
phase_borough_summary = (
    df.groupby(['covid_phase', 'borough'], as_index=False)['consumption_(kwh)']
    .sum()
)

# Plotting
fig = px.bar(
    phase_borough_summary,
    x='covid_phase',
    y='consumption_(kwh)',
    color='borough',
    barmode='group',
    text='consumption_(kwh)',
    title="Electricity Consumption by Borough and COVID Phase (NYCHA)",
    color_discrete_sequence=px.colors.qualitative.Set2
)

# Format text and layout
fig.update_traces(texttemplate='%{text:.2s}', textposition='outside')
fig.update_layout(
    yaxis_title="Total kWh (M = Million, G = Billion)",
    xaxis_title="COVID Phase",
    template="plotly_white",
    yaxis_tickformat=".2s",
    showlegend=True
)

fig.show()
# Out:
# <ipython-input-93-c26e2b8b8db5>:5: FutureWarning:
#
# The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="ebb1390b-b639-4a90-bcdc-363e9753ab4c" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("ebb1390b-b639-4a90-bcdc-363e9753ab4c")) {                    Plotly.newPlot(                        "ebb1390b-b639-4a90-bcdc-363e9753ab4c",                        [{"alignmentgroup":"True","hovertemplate":"borough=Brooklyn\u003cbr\u003ecovid_phase=%{x}\u003cbr\u003econsumption_(kwh)=%{text}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Brooklyn","marker":{"color":"rgb(102,194,165)","pattern":{"shape":""}},"name":"Brooklyn","offsetgroup":"Brooklyn","orientation":"v","showlegend":true,"text":[0.0,0.0,0.0],"textposition":"outside","x":["Before","COVID","After"],"xaxis":"x","y":[0.0,0.0,0.0],"yaxis":"y","type":"bar","texttemplate":"%{text:.2s}"},{"alignmentgroup":"True","hovertemplate":"borough=Manhattan\u003cbr\u003ecovid_phase=%{x}\u003cbr\u003econsumption_(kwh)=%{text}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Manhattan","marker":{"color":"rgb(252,141,98)","pattern":{"shape":""}},"name":"Manhattan","offsetgroup":"Manhattan","orientation":"v","showlegend":true,"text":[0.0,0.0,0.0],"textposition":"outside","x":["Before","COVID","After"],"xaxis":"x","y":[0.0,0.0,0.0],"yaxis":"y","type":"bar","texttemplate":"%{text:.2s}"},{"alignmentgroup":"True","hovertemplate":"borough=Bronx\u003cbr\u003ecovid_phase=%{x}\u003cbr\u003econsumption_(kwh)=%{text}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Bronx","marker":{"color":"rgb(141,160,203)","pattern":{"shape":""}},"name":"Bronx","offsetgroup":"Bronx","orientation":"v","showlegend":true,"text":[0.0,0.0,0.0],"textposition":"outside","x":["Before","COVID","After"],"xaxis":"x","y":[0.0,0.0,0.0],"yaxis":"y","type":"bar","texttemplate":"%{text:.2s}"},{"alignmentgroup":"True","hovertemplate":"borough=Queens\u003cbr\u003ecovid_phase=%{x}\u003cbr\u003econsumption_(kwh)=%{text}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Queens","marker":{"color":"rgb(231,138,195)","pattern":{"shape":""}},"name":"Queens","offsetgroup":"Queens","orientation":"v","showlegend":true,"text":[0.0,0.0,0.0],"textposition":"outside","x":["Before","COVID","After"],"xaxis":"x","y":[0.0,0.0,0.0],"yaxis":"y","type":"bar","texttemplate":"%{text:.2s}"},{"alignmentgroup":"True","hovertemplate":"borough=Staten Island\u003cbr\u003ecovid_phase=%{x}\u003cbr\u003econsumption_(kwh)=%{text}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Staten Island","marker":{"color":"rgb(166,216,84)","pattern":{"shape":""}},"name":"Staten Island","offsetgroup":"Staten Island","orientation":"v","showlegend":true,"text":[0.0,0.0,0.0],"textposition":"outside","x":["Before","COVID","After"],"xaxis":"x","y":[0.0,0.0,0.0],"yaxis":"y","type":"bar","texttemplate":"%{text:.2s}"}],                        {"template":{"data":{"barpolar":[{"marker":{"line":{"color":"white","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"barpolar"}],"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"white","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"carpet":[{"aaxis":{"endlinecolor":"#2a3f5f","gridcolor":"#C8D4E3","linecolor":"#C8D4E3","minorgridcolor":"#C8D4E3","startlinecolor":"#2a3f5f"},"baxis":{"endlinecolor":"#2a3f5f","gridcolor":"#C8D4E3","linecolor":"#C8D4E3","minorgridcolor":"#C8D4E3","startlinecolor":"#2a3f5f"},"type":"carpet"}],"choropleth":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"choropleth"}],"contourcarpet":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"contourcarpet"}],"contour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.222222 ...
